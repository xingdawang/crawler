# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent': 'Mozilla/5.0'}

page = requests.get('https://sh.meituan.com/meishi/', headers = headers)

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="meituan.com" name="for"/>
#   <title>
#    【上海美食】全部美食推荐_美食攻略-上海美团网
#   </title>
#   <meta content="美团上海+美食，查找全部美食图片，特色美食，美食餐厅，查询菜单，人均价格，营业时间，优惠的最新信息。上万用户的美食评价，推荐靠谱特色美食店。" name="description"/>
#   <meta content="上海+美食，美食图片，特色美食，美食餐厅。" name="keyword"/>
#   <meta content="upgrade-insecure-requests" http-equiv="Content-Security-Policy"/>
#   <link href="//analytics.meituan.net" rel="dns-prefetch"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <script>
# ...
